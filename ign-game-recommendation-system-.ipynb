# %% [markdown]
# # IGN Games - Recommendation System
#
# ## About Dataset
#
# - In 20 years, the gaming industry has grown sophisticated. By exploring this dataset, one will be able to find trends about industries, compare consoles against each other, search through the most popular genres and more.
# - It contains 18625 data points with various features such as release dates with different platform along with IGN scores.
#
# In this project, a Recommendation System has been built using the cosine similarity metric, and the approach employed is Content-Based Recommendation. This recommendation system analyzes and suggests game recommendations to users based on the content and features of the games themselves. The content features used include game genres, score, score phrase, release date, platform, and URL. By calculating the cosine similarity between game content vectors represented using TF-IDF (Term Frequency-Inverse Document Frequency) features, the system identifies games that are similar in terms of their content and provides personalized recommendations to users.
#
# Source: https://www.kaggle.com/datasets/joebeachcapital/ign-games

# %% [markdown]
# # Importing Libaray and Loading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
data = pd.read_csv("https://raw.githubusercontent.com/rachanabv07/Games-Recommendation-System/main/IGN%20Game%20Dataset.csv")
data.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
# original shape of dataset
data.shape
# Out:
# (18625, 11)

# %% [markdown]
# # Data Preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18625 entries, 0 to 18624
# Data columns (total 11 columns):
# Unnamed: 0        18625 non-null int64
# score_phrase      18625 non-null object
# title             18625 non-null object
# url               18625 non-null object
# platform          18625 non-null object
# score             18625 non-null float64
# genre             18589 non-null object
# editors_choice    18625 non-null object
# release_year      18625 non-null int64
# release_month     18625 non-null int64
# release_day       18625 non-null int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.6+ MB

# %%
# Checking for null values
data.isnull().sum()
# Out:
# Unnamed: 0         0
# score_phrase       0
# title              0
# url                0
# platform           0
# score              0
# genre             36
# editors_choice     0
# release_year       0
# release_month      0
# release_day        0
# dtype: int64

# %%
# viewing NaN rows
data_nonnull = data[data.isnull().any(axis = 1)]
data_nonnull
# Out:
#        Unnamed: 0 score_phrase  \
# 12             12         Good
# 113           113         Good
# 160           160         Good
# 176           176         Okay
# 9375         9375        Great
# 9488         9488         Okay
# 9767         9767         Good
# 9774         9774      Amazing
# 10494       10494        Awful
# 11367       11367      Painful
# 11513       11513         Good
# 11699       11699     Mediocre
# 11719       11719        Great
# 12316       12316          Bad
# 12620       12620         Good
# 12865       12865         Okay
# 13527       13527        Great
# 13754       13754         Good
# 14070       14070         Good
# 14099       14099        Great
# 14259       14259        Great
# 14729       14729         Good
# 14769       14769         Okay
# 14911       14911         Okay
# 15279       15279         Good
# 15552       15552        Great
# 15578       15578         Good
# 15579       15579         Good
# 15580       15580         Good
# 15589       15589        Great
# 15608       15608         Good
# 16136       16136     Mediocre
# 16179       16179         Good
# 16953       16953        Great
# 17686       17686        Awful
# 17705       17705         Good
#
#                                                    title  \
# 12                                            Wild Blood
# 113                                          Retro/Grade
# 160                                             10000000
# 176                                          Colour Bind
# 9375                                    Duke Nukem Arena
# 9488                                             Rengoku
# 9767                                      Super Sketcher
# 9774                                      Critter Crunch
# 10494       Clue / Mouse Trap / Perfection / Aggravation
# 11367                                       Jeep Thrills
# 11513                                   21 Pro Blackjack
# 11699                                       Golden Skull
# 11719          Nancy Drew: The Haunting of Castle Malloy
# 12316                                     PopStar Guitar
# 12620                                         Heavy Mach
# 12865                                      Tower Toppler
# 13527                                Eyegore's Eye Blast
# 13754                         Aha! I Got It! Escape Game
# 14070                                         ShadowPlay
# 14099                               The Horrible Vikings
# 14259                                           The Hero
# 14729                                           Primrose
# 14769                                          AquaSpace
# 14911                              Meow Meow Happy Fight
# 15279                Stenches: A Zombie Tale of Trenches
# 15552                                       Land-a Panda
# 15578                     Naruto Shippuden: Kizuna Drive
# 15579    Nintendogs + Cats: French Bulldog & New Friends
# 15580        Nintendogs + Cats: Toy Poodle & New Friends
# 15589                                          Liqua Pop
# 15608  Nintendogs + Cats: Golden Retriever & New Friends
# 16136                         Crystal Caverns of Amon-Ra
# 16179                         Aya and the Cubes of Light
# 16953                                    Impossible Road
# 17686                                 War of the Vikings
# 17705                                         Boom Beach
#
#                                                      url  \
# 12                       /games/wild-blood/iphone-139363
# 113                   /games/retrograde-138590/ps3-21766
# 160                        /games/10000000/iphone-139135
# 176                         /games/colour-bind/pc-143757
# 9375                 /games/duke-nukem-arena/cell-893821
# 9488                          /games/rengoku/cell-924924
# 9767                   /games/super-sketcher/cell-874054
# 9774                   /games/critter-crunch/cell-963486
# 10494  /games/clue-mouse-trap-perfection-aggravation/...
# 11367                   /games/jeep-thrills/ps2-14246598
# 11513            /games/21-pro-blackjack/iphone-14277696
# 11699                /games/golden-skull/iphone-14287451
# 11719  /games/nancy-drew-the-haunting-of-castle-mallo...
# 12316                 /games/popstar-guitar/ps2-14268729
# 12620                  /games/heavy-mach/iphone-14327354
# 12865                  /games/tower-toppler/c64-14346603
# 13527             /games/eyegores-eye-blast/iphone-37398
# 13754          /games/aha-i-got-it-escape-game/wii-24790
# 14070                        /games/shadowplay/wii-38484
# 14099           /games/the-horrible-vikings/iphone-57466
# 14259                       /games/the-hero/iphone-64997
# 14729                          /games/primrose/dsi-60745
# 14769                         /games/aquaspace/wii-81231
# 14911          /games/meow-meow-happy-fight/iphone-83939
# 15279  /games/stenches-a-zombie-tale-of-trenches/ipho...
# 15552                  /games/land-a-panda/iphone-103171
# 15578     /games/naruto-shippuden-kizuna-drive/psp-65765
# 15579  /games/nintendogs-cats-french-bulldog-new-frie...
# 15580  /games/nintendogs-plus-cats-toy-poodle-and-new...
# 15589                     /games/liqua-pop/iphone-103253
# 15608  /games/nintendogs-plus-cats-golden-retriever-n...
# 16136       /games/crystal-caverns-of-amon-ra/dsi-119103
# 16179       /games/aya-and-the-cubes-of-light/wii-118626
# 16953               /games/impossible-road/iphone-167650
# 17686              /games/war-of-the-vikings/pc-20014258
# 17705                  /games/boom-beach/iphone-20013310
#
#                    platform  score genre editors_choice  release_year  \
# 12                   iPhone    7.0   NaN              N          2012
# 113           PlayStation 3    7.0   NaN              N          2012
# 160                  iPhone    7.5   NaN              N          2012
# 176                      PC    6.2   NaN              N          2012
# 9375               Wireless    8.0   NaN              Y          2007
# 9488               Wireless    6.5   NaN              N          2007
# 9767               Wireless    7.5   NaN              N          2007
# 9774               Wireless    9.0   NaN              Y          2007
# 10494           Nintendo DS    3.5   NaN              N          2008
# 11367         PlayStation 2    2.0   NaN              N          2008
# 11513                iPhone    7.0   NaN              N          2008
# 11699                iPhone    5.0   NaN              N          2008
# 11719                    PC    8.0   NaN              N          2008
# 12316         PlayStation 2    4.0   NaN              N          2008
# 12620                iPhone    7.8   NaN              N          2009
# 12865      Commodore 64/128    6.0   NaN              N          2009
# 13527                iPhone    8.0   NaN              N          2009
# 13754                   Wii    7.0   NaN              N          2009
# 14070                   Wii    7.5   NaN              N          2010
# 14099                iPhone    8.0   NaN              N          2010
# 14259                iPhone    8.0   NaN              N          2010
# 14729          Nintendo DSi    7.5   NaN              N          2010
# 14769                   Wii    6.0   NaN              N          2010
# 14911                iPhone    6.5   NaN              N          2010
# 15279                iPhone    7.5   NaN              N          2010
# 15552                iPhone    8.0   NaN              N          2011
# 15578  PlayStation Portable    7.0   NaN              N          2011
# 15579          Nintendo 3DS    7.0   NaN              N          2011
# 15580          Nintendo 3DS    7.0   NaN              N          2011
# 15589                iPhone    8.0   NaN              N          2011
# 15608          Nintendo 3DS    7.0   NaN              N          2011
# 16136          Nintendo DSi    5.0   NaN              N          2011
# 16179                   Wii    7.0   NaN              N          2011
# 16953                iPhone    8.4   NaN              N          2013
# 17686                    PC    3.5   NaN              N          2014
# 17705                iPhone    7.0   NaN              N          2014
#
#        release_month  release_day
# 12                 9           10
# 113                8           15
# 160                8            9
# 176               10           15
# 9375               6           15
# 9488               6           26
# 9767               9           14
# 9774               9           13
# 10494              1           23
# 11367              8           18
# 11513              9            9
# 11699             10            6
# 11719             10            8
# 12316             12           18
# 12620              3            5
# 12865              5            5
# 13527             10            5
# 13754             11            3
# 14070              1           20
# 14099              1           22
# 14259              3           19
# 14729              7           21
# 14769              7           28
# 14911              8           18
# 15279             11           16
# 15552              3           14
# 15578              3           24
# 15579              3           23
# 15580              3           23
# 15589              3           18
# 15608              3           23
# 16136              9           29
# 16179              9           22
# 16953              5           31
# 17686              4           23
# 17705              4           16

# %%
# Dropping NaN rows
rem_na_data = data.dropna(axis=0)

# %%
# Checking for NaN values
rem_na_data.isnull().sum()
# Out:
# Unnamed: 0        0
# score_phrase      0
# title             0
# url               0
# platform          0
# score             0
# genre             0
# editors_choice    0
# release_year      0
# release_month     0
# release_day       0
# dtype: int64

# %%
rem_na_data.columns
# Out:
# Index(['Unnamed: 0', 'score_phrase', 'title', 'url', 'platform', 'score',
#        'genre', 'editors_choice', 'release_year', 'release_month',
#        'release_day'],
#       dtype='object')

# %%
# Merging Year, Month, Day columns to one column
rem_na_data['release_date'] = pd.to_datetime(rem_na_data[['release_year', 'release_month', 'release_day']].astype(str).agg('-'.join, axis=1))
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rem_na_data.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day  \
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11
#
#   release_date
# 0   2012-09-12
# 1   2012-09-12
# 2   2012-09-12
# 3   2012-09-11
# 4   2012-09-11

# %%
#Dropping 
rem_na_data.drop(['Unnamed: 0','release_year', 'release_month', 'release_day'], axis=1, inplace=True)
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
rem_na_data.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice release_date
# 0  Platformer              Y   2012-09-12
# 1  Platformer              Y   2012-09-12
# 2      Puzzle              N   2012-09-12
# 3      Sports              N   2012-09-11
# 4      Sports              N   2012-09-11

# %%
rem_na_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18589 entries, 0 to 18624
# Data columns (total 8 columns):
# score_phrase      18589 non-null object
# title             18589 non-null object
# url               18589 non-null object
# platform          18589 non-null object
# score             18589 non-null float64
# genre             18589 non-null object
# editors_choice    18589 non-null object
# release_date      18589 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 1.3+ MB

# %%
dataset = rem_na_data

# %%
# dropping duplicates with refers to url column
dataset.drop_duplicates(subset='url', keep='first', inplace=True)
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Shape of dataset after cleaning
dataset.shape
# Out:
# (18541, 8)

# %%
dataset.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice release_date
# 0  Platformer              Y   2012-09-12
# 1  Platformer              Y   2012-09-12
# 2      Puzzle              N   2012-09-12
# 3      Sports              N   2012-09-11
# 4      Sports              N   2012-09-11

# %%
# Exploring unique platform names
print("Platform Names : ",dataset['platform'].unique())
print("Number of different Platform : ", len(dataset['platform'].unique()))
# Out:
# Platform Names :  ['PlayStation Vita' 'iPad' 'Xbox 360' 'PlayStation 3' 'Macintosh' 'PC'
#  'iPhone' 'Nintendo DS' 'Nintendo 3DS' 'Android' 'Wii' 'PlayStation 4'
#  'Wii U' 'Linux' 'PlayStation Portable' 'PlayStation' 'Nintendo 64'
#  'Saturn' 'Lynx' 'Game Boy' 'Game Boy Color' 'NeoGeo Pocket Color'
#  'Game.Com' 'Dreamcast' 'Dreamcast VMU' 'WonderSwan' 'Arcade'
#  'Nintendo 64DD' 'PlayStation 2' 'WonderSwan Color' 'Game Boy Advance'
#  'Xbox' 'GameCube' 'DVD / HD Video Game' 'Wireless' 'Pocket PC' 'N-Gage'
#  'NES' 'iPod' 'Genesis' 'TurboGrafx-16' 'Super NES' 'NeoGeo'
#  'Master System' 'Atari 5200' 'TurboGrafx-CD' 'Atari 2600' 'Sega 32X'
#  'Vectrex' 'Commodore 64/128' 'Sega CD' 'Nintendo DSi' 'Windows Phone'
#  'Web Games' 'Xbox One' 'Windows Surface' 'Ouya' 'New Nintendo 3DS'
#  'SteamOS']
# Number of different Platform :  59

# %%
# Exploring unique genre names
print("Genre Names : ",dataset['genre'].unique())
print("Number of different Genre : ", len(dataset['genre'].unique()))
# Out:
# Genre Names :  ['Platformer' 'Puzzle' 'Sports' 'Strategy' 'Fighting' 'RPG'
#  'Action, Adventure' 'Adventure' 'Action' 'Action, RPG' 'Shooter' 'Music'
#  'Board' 'Racing' 'Strategy, RPG' 'Racing, Action' 'Shooter, RPG'
#  'Simulation' 'Action, Simulation' 'Flight, Action' 'Puzzle, Action'
#  'Action, Compilation' 'Educational, Puzzle' 'Wrestling'
#  'Fighting, Action' 'Productivity' 'Sports, Simulation' 'Music, Action'
#  'Sports, Action' 'Party' 'Battle' 'Puzzle, Adventure' 'Puzzle, Word Game'
#  'Card, Battle' 'Simulation, Adventure' 'Compilation' 'Flight' 'Pinball'
#  'Hunting' 'Casino' 'Sports, Racing' 'Fighting, Compilation'
#  'Flight, Simulation' 'Trivia' 'Action, Platformer' 'Other' 'Virtual Pet'
#  'Music, Editor' 'Sports, Editor' 'Racing, Simulation' 'RPG, Editor'
#  'Educational, Action' 'Card' 'Card, RPG' 'Wrestling, Simulation'
#  'Fighting, Adventure' 'Sports, Compilation' 'RPG, Compilation'
#  'Flight, Racing' 'RPG, Simulation' 'Shooter, Platformer' 'Fighting, RPG'
#  'Card, Compilation' 'Hunting, Simulation' 'Pinball, Compilation'
#  'Racing, Shooter' 'Racing, Editor' 'Other, Action' 'Racing, Compilation'
#  'Adult, Card' 'Puzzle, Compilation' 'Platformer, Action' 'Educational'
#  'Action, Editor' 'Board, Compilation' 'Hunting, Action'
#  'Educational, Trivia' 'Compilation, Compilation'
#  'Educational, Simulation' 'Educational, Productivity'
#  'Adventure, Compilation' 'Educational, Card' 'Educational, Adventure'
#  'Fighting, Simulation' 'Music, Compilation' 'Strategy, Compilation'
#  'Platformer, Adventure' 'Other, Adventure' 'Adventure, Episodic'
#  'Adventure, Adult' 'Puzzle, RPG' 'Sports, Fighting'
#  'Adventure, Platformer' 'Action, Puzzle' 'Sports, Other'
#  'Compilation, RPG' 'Shooter, First-Person' 'Adventure, Adventure'
#  'Sports, Party' 'Sports, Baseball' 'Baseball' 'Music, RPG'
#  'Productivity, Action' 'RPG, Action' 'Adventure, RPG'
#  'Strategy, Simulation' 'Action, Strategy' 'Puzzle, Platformer'
#  'Music, Adventure' 'Sports, Golf' 'Hardware' 'Shooter, Adventure']
# Number of different Genre :  112

# %%
# Merging the same games with different platforms
merged_df = dataset.groupby('title').agg({
    'score_phrase': 'first',          # Take the first value of 'score_phrase'
    'url': ' & '.join,                  # Join all 'url' values with '|'
    'platform': ', '.join,            # Join all 'platform' values with '|'
    'score': 'mean',                 # Calculate the mean of 'score'
    'genre': 'first',                # Take the first value of 'genre'
    'editors_choice': 'first',       # Take the first value of 'editors_choice'
    'release_date': 'first'          # Take the first value of 'release_date'
}).reset_index()

# %%
merged_df.tail()
# Out:
#                          title score_phrase  \
# 12551              kill.switch        Great
# 12552                 realMyst         Okay
# 12553             ruthless.com     Mediocre
# 12554                      xXx         Okay
# 12555  xXx: State of the Union        Great
#
#                                                      url  \
# 12551  /games/killswitch/xbox-566615 & /games/killswi...
# 12552                           /games/realmyst/pc-15612
# 12553                        /games/ruthlesscom/pc-10831
# 12554                              /games/xxx/gba-481995
# 12555          /games/xxx-state-of-the-union/cell-745524
#
#                                         platform  score      genre  \
# 12551  Xbox, PlayStation 2, PC, Game Boy Advance  7.825    Shooter
# 12552                                         PC  6.500  Adventure
# 12553                                         PC  5.200   Strategy
# 12554                           Game Boy Advance  6.000     Action
# 12555                                   Wireless  8.000     Action
#
#       editors_choice release_date
# 12551              N   2003-10-27
# 12552              N   2000-11-13
# 12553              N   1999-01-19
# 12554              N   2002-08-09
# 12555              Y   2005-05-03

# %%
# Final dataset shape
merged_df.shape
# Out:
# (12556, 8)

# %% [markdown]
# # Content Vectorization

# %%
# merging genre, score, score_phrase, platform, url, date to one column
merged_df['content'] = merged_df["genre"]+", "+ merged_df["score_phrase"]+", "+merged_df["score"].astype(str)+", "+merged_df["platform"]+", "+merged_df["url"]

# %%
merged_df.tail()
# Out:
#                          title score_phrase  \
# 12551              kill.switch        Great
# 12552                 realMyst         Okay
# 12553             ruthless.com     Mediocre
# 12554                      xXx         Okay
# 12555  xXx: State of the Union        Great
#
#                                                      url  \
# 12551  /games/killswitch/xbox-566615 & /games/killswi...
# 12552                           /games/realmyst/pc-15612
# 12553                        /games/ruthlesscom/pc-10831
# 12554                              /games/xxx/gba-481995
# 12555          /games/xxx-state-of-the-union/cell-745524
#
#                                         platform  score      genre  \
# 12551  Xbox, PlayStation 2, PC, Game Boy Advance  7.825    Shooter
# 12552                                         PC  6.500  Adventure
# 12553                                         PC  5.200   Strategy
# 12554                           Game Boy Advance  6.000     Action
# 12555                                   Wireless  8.000     Action
#
#       editors_choice release_date  \
# 12551              N   2003-10-27
# 12552              N   2000-11-13
# 12553              N   1999-01-19
# 12554              N   2002-08-09
# 12555              Y   2005-05-03
#
#                                                  content
# 12551  Shooter, Great, 7.825, Xbox, PlayStation 2, PC...
# 12552  Adventure, Okay, 6.5, PC, /games/realmyst/pc-1...
# 12553  Strategy, Mediocre, 5.2, PC, /games/ruthlessco...
# 12554  Action, Okay, 6.0, Game Boy Advance, /games/xx...
# 12555  Action, Great, 8.0, Wireless, /games/xxx-state...

# %%
# Use techniques like TF-IDF (Term Frequency-Inverse Document Frequency) to convert textual features into numerical vectors.
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(merged_df['content'])

# %% [markdown]
# # Similarity Calculation

# %%
#Calculating the cosine similarity between game content
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# Create a reverse mapping of game titles to DataFrame indices
indices = pd.Series(merged_df.index, index=merged_df['title'])

# %%
indices
# Out:
# title
# #IDARB                               0
# 'Splosion Man                        1
# .deTuned                             2
# .hack//G.U. Vol. 1: Rebirth          3
# .hack//G.U. Vol. 2: Reminisce        4
#                                  ...
# kill.switch                      12551
# realMyst                         12552
# ruthless.com                     12553
# xXx                              12554
# xXx: State of the Union          12555
# Length: 12556, dtype: int64

# %% [markdown]
# # Function to get Game Recommendations

# %%
# Function to get game recommendations 
def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx])) #similarity scores of all games with that game
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) # Sort the games based on the similarity scores
    sim_scores = sim_scores[1:11]  # Top 10 similar games (excluding the input game)
    game_indices = [i[0] for i in sim_scores]
    recommendations = merged_df.iloc[game_indices][['title','genre','score', 'score_phrase','release_date','platform', 'url']]
    recommendations['Number of Recommendations'] = range(1,len(recommendations)+1)
    
    recommendations = recommendations.rename(columns={
        'title': 'Game Names',
        'score_phrase': 'Review',
        'url': 'URL',
        'platform': 'Platform',
        'score': 'Score',
        'genre': 'Genre',
        'release_date': 'Release Date'
    })
    return recommendations

# %% [markdown]
# # Top 10 Game Recommendations

# %%
#Randomly picking Game name for dataset
import random
for i in range(len(merged_df['title'])+50):   
    ran = int(random.random()*len(merged_df['title']))
    Game_name = merged_df['title'][ran]
merged_df.loc[merged_df['title'] == Game_name]
# Out:
#                  title score_phrase  \
# 4771  Hole In The Wall     Mediocre
#
#                                                  url  platform  score  \
# 4771  /games/hole-in-the-wall-108893/xbox-360-108892  Xbox 360    5.0
#
#                genre editors_choice release_date  \
# 4771  Puzzle, Action              N   2011-08-25
#
#                                                 content
# 4771  Puzzle, Action, Mediocre, 5.0, Xbox 360, /game...

# %%
# Top 10 recommendations based on one input game
recommendations = get_recommendations(Game_name)
print("Recommendations for", Game_name, ":")
result = pd.DataFrame(recommendations)
result
# Out:
# Recommendations for Hole In The Wall :
#                 Game Names              Genre  Score    Review Release Date  \
# 11843               WALL-E  Action, Adventure    6.1      Good   2008-07-03
# 8156         Puzzle Arcade             Puzzle    5.0  Mediocre   2009-01-05
# 12186          Word Puzzle             Puzzle    5.5  Mediocre   2007-11-07
# 10156         Super Contra             Action    5.7  Mediocre   2007-07-26
# 3419                Exit 2     Puzzle, Action    6.5      Okay   2009-02-25
# 9240          Shrek-N-Roll             Puzzle    5.5  Mediocre   2007-11-15
# 10500             Tenchu Z  Action, Adventure    5.2  Mediocre   2007-06-19
# 4167        Geon: Emotions     Puzzle, Action    6.8      Okay   2007-09-27
# 1055   Bejeweled 2: Deluxe             Puzzle    7.8      Good   2006-06-13
# 3242        Eets: Chowdown     Puzzle, Action    7.4      Good   2007-04-26
#
#                                                 Platform  \
# 11843  PlayStation Portable, Nintendo DS, PlayStation...
# 8156                                            Xbox 360
# 12186                                           Xbox 360
# 10156                                           Xbox 360
# 3419                                            Xbox 360
# 9240                                            Xbox 360
# 10500                                           Xbox 360
# 4167                                            Xbox 360
# 1055                                            Xbox 360
# 3242                                            Xbox 360
#
#                                                      URL  \
# 11843  /games/wall-e/psp-14226081 & /games/wall-e/nds...
# 8156              /games/puzzle-arcade/xbox-360-14290789
# 12186                 /games/word-puzzle/xbox-360-949562
# 10156                     /games/super-c/xbox-360-952133
# 3419                     /games/exit-2/xbox-360-14318701
# 9240               /games/shrek-n-roll/xbox-360-14214944
# 10500                    /games/tenchu-z/xbox-360-772077
# 4167                         /games/geon/xbox-360-949558
# 1055                  /games/bejeweled-2/xbox-360-777187
# 3242                         /games/eets/xbox-360-881247
#
#        Number of Recommendations
# 11843                          1
# 8156                           2
# 12186                          3
# 10156                          4
# 3419                           5
# 9240                           6
# 10500                          7
# 4167                           8
# 1055                           9
# 3242                          10
